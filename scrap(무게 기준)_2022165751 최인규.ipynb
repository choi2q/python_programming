# %% [markdown]
# <a href="https://colab.research.google.com/github/choi2q/python_programming/blob/main/scrap(%EB%AC%B4%EA%B2%8C%20%EA%B8%B0%EC%A4%80)_2022165751%20%EC%B5%9C%EC%9D%B8%EA%B7%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gdown

gdown.download('https://bit.ly/3q9SZix', '20s_best_book.json', quiet=False)
# Out:
# Downloading...
# From: https://bit.ly/3q9SZix
# To: /content/20s_best_book.json
# 100%|██████████| 92.9k/92.9k [00:00<00:00, 23.0MB/s]
# '20s_best_book.json'

# %%
import pandas as pd

books_df = pd.read_json('20s_best_book.json')
books_df.head(20)
# Out:
#     no  ranking                                 bookname  \
# 0    1        1              우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 1    2        2                     달러구트 꿈 백화점.이미예 장편소설
# 2    3        3                      지구에서 한아뿐 :정세랑 장편소설
# 3    4        4                       시선으로부터, :정세랑 장편소설
# 4    5        5                           아몬드 :손원평 장편소설
# 5    6        6                        피프티 피플 :정세랑 장편소설
# 6    7        7                      목소리를 드릴게요 :정세랑 소설집
# 7    8        8              나미야 잡화점의 기적 :히가시노 게이고 장편소설
# 8    9        9                               선량한 차별주의자
# 9   10        9                          쇼코의 미소 :최은영 소설
# 10  11       11                       천 개의 파랑 :천선란 장편소설
# 11  12       12                      일의 기쁨과 슬픔 :장류진 소설집
# 12  13       13       공정하다는 착각 :능력주의는 모두에게 같은 기회를 제공하는가
# 13  14       14  사피엔스 :유인원에서 사이보그까지, 인간 역사의 대담하고 위대한 질문
# 14  15       15                       내게 무해한 사람 :최은영 소설
# 15  16       16                         소년이 온다 :한강 장편소설
# ...

# %%
books = books_df.loc[:, 'no':'isbn13']
books.head()
# Out:
#    no  ranking                     bookname   authors publisher  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   지은이: 김초엽        허블
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설   지은이: 이미예     팩토리나인
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설   지은이: 정세랑        난다
# 3   4        4           시선으로부터, :정세랑 장편소설   지은이: 정세랑      문학동네
# 4   5        5               아몬드 :손원평 장편소설   지은이: 손원평        창비
#
#   publication_year         isbn13
# 0             2019  9791190090018
# 1             2020  9791165341909
# 2             2019  9791188862290
# 3             2020  9788954672214
# 4             2017  9788936434267

# %%
  import requests

  requests.packages.urllib3.util.ssl_.DEFAULT_CIPHERS += 'HIGH:!DH:!aNULL'
  try:
      requests.packages.urllib3.contrib.pyopenssl.DEFAULT_SSL_CIPHER_LIST += 'HIGH:!DH:!aNULL'
  except AttributeError:
      # no pyopenssl support used / needed / available
      pass

# %%
import requests

isbn = 9791165341909      # '달러구트 꿈 백화점.이미예 장편소설'의 ISBN
url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'

r = requests.get(url.format(isbn))

# %%
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title> 9791165341909 - 예스24</title>
#
# 	<meta name="title" content="예스24" />
# 	<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" />
#
#
# 	<link title="YES24" rel="search" type="application/opensearchdescription+xml" href="//www.yes24.com/OpensearchDescription.xml">
#
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
prd_link = soup.find('a', attrs={'class':'gd_name'})

# %%
print(prd_link)
# Out:
# <a class="gd_name" href="/Product/Goods/91065309" onclick="setSCode('101_005_003_001');setGoodsClickExtraCodeHub('032', '9791165341909', '91065309', '0');">달러구트 꿈 백화점 </a>

# %%
print(prd_link['href'])
# Out:
# /Product/Goods/91065309

# %%
# '달러구트 꿈 백화점.이미예 장편소설'의 상세 페이지 가져오기
url = 'http://www.yes24.com'+prd_link['href']
r = requests.get(url)

# %%
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head><link rel="canonical" href="https://www.yes24.com/Product/Goods/91065309"> <link rel="alternate" media="only screen and(max-width: 640px)"  href="https://m.yes24.com/Goods/Detail/91065309">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title> 달러구트 꿈 백화점  - YES24 </title>
#
#
# <meta name="title" content="달러구트 꿈 백화점  - YES24"/>
# <meta name="author" content="이미예" />
#
# ...

# %%
soup = BeautifulSoup(r.text, 'html.parser')
prd_detail = soup.find('div', attrs={'id':'infoset_specific'})
print(prd_detail)
# Out:
# <div class="gd_infoSet infoSet_noLine" id="infoset_specific">
# <div class="tm_infoSet">
# <h4 class="tit_txt">품목정보</h4>
# </div>
# <div class="infoSetCont_wrap">
# <div class="yesTb">
# <table class="tb_nor tb_vertical" summary="품목정보 국내도서, 외국도서 " width="100%">
# <caption>품목정보</caption>
# <colgroup>
# <col width="170"/>
# <col width="*"/>
# </colgroup>
# <tbody class="b_size">
# <tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2020년 07월 08일</td>
# </tr>
# <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">300쪽 | 358g | 134*200*20mm</td>
# </tr>
# <tr>
# <th class="txt" scope="row">ISBN13</th>
# <td class="txt lastCol">9791165341909</td>
# </tr>
# <tr>
# <th class="txt" scope="row">ISBN10</th>
# <td class="txt lastCol">1165341905</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# <script type="text/javascript">
#         if ($("#infoset_specific table tbody tr").length == 0) {
#             $("#infoset_specific").remove();
# ...

# %%
prd_tr_list = prd_detail.find_all('tr')
print(prd_tr_list)
# Out:
# [<tr>
# <th class="txt" scope="row">발행일</th>
# <td class="txt lastCol">2020년 07월 08일</td>
# </tr>, <tr>
# <th class="txt" scope="row">쪽수, 무게, 크기</th>
# <td class="txt lastCol">300쪽 | 358g | 134*200*20mm</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN13</th>
# <td class="txt lastCol">9791165341909</td>
# </tr>, <tr>
# <th class="txt" scope="row">ISBN10</th>
# <td class="txt lastCol">1165341905</td>
# </tr>]

# %%
for tr in prd_tr_list:
    if tr.find('th').get_text() == '쪽수, 무게, 크기':
        page_td = tr.find('td').get_text()
        break

# %%
print(page_td)
# Out:
# 300쪽 | 358g | 134*200*20mm

# %%
print(page_td.split()[2])
# Out:
# 358g

# %%
def get_무게_cnt(isbn):
    # Yes24 도서 검색 페이지 URL
    url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
    # URL에 ISBN을 넣어 HTML 가져옵니다.
    r = requests.get(url.format(isbn))
    soup = BeautifulSoup(r.text, 'html.parser')   # HTML 파싱
    # 검색 결과에서 해당 도서를 선택합니다.
    prd_info = soup.find('a', attrs={'class':'gd_name'})
    if prd_info == None:
        return ''
    # 도서 상세 페이지를 가져옵니다.
    url = 'http://www.yes24.com'+prd_info['href']
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    # 상품 상세정보 div를 선택합니다.
    prd_detail = soup.find('div', attrs={'id':'infoset_specific'})
    # 테이블에 있는 tr 태그를 가져옵니다.
    prd_tr_list = prd_detail.find_all('tr')
    # 쪽수가 들어 있는 th를 찾아 td에 담긴 값을 반환합니다.
    for tr in prd_tr_list:
        if tr.find('th').get_text() == '쪽수, 무게, 크기':
            return tr.find('td').get_text().split()[2]
    return ''

# %%
get_무게_cnt(9791190090018)
# Out:
# '496g'

# %%
top10_books = books.head(10)

# %%
def get_무게_cnt2(row):
    isbn = row['isbn13']
    return get_무게_cnt(isbn)

# %%
무게_count = top10_books.apply(get_무게_cnt2, axis=1)
print(무게_count)
# Out:
# 0    496g
# 1    358g
# 2    296g
# 3    412g
# 4    388g
# 5    512g
# 6    318g
# 7
# 8    324g
# 9    406g
# dtype: object

# %%
무게_count = top10_books.apply(lambda row: get_무게_cnt(row['isbn13']), axis=1)

# %%
무게_count.name = '무게_count'
print(무게_count)
# Out:
# 0    496g
# 1    358g
# 2    296g
# 3    412g
# 4    388g
# 5    512g
# 6    318g
# 7
# 8    324g
# 9    406g
# Name: 무게_count, dtype: object

# %%
top10_with_무게_count = pd.merge(top10_books, 무게_count, 
                                 left_index=True, right_index=True)
top10_with_무게_count
# Out:
#    no  ranking                     bookname                  authors  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설                  지은이: 김초엽
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설                  지은이: 이미예
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설                  지은이: 정세랑
# 3   4        4           시선으로부터, :정세랑 장편소설                  지은이: 정세랑
# 4   5        5               아몬드 :손원평 장편소설                  지은이: 손원평
# 5   6        6            피프티 피플 :정세랑 장편소설                  지은이: 정세랑
# 6   7        7          목소리를 드릴게요 :정세랑 소설집                  지은이: 정세랑
# 7   8        8  나미야 잡화점의 기적 :히가시노 게이고 장편소설   지은이: 히가시노 게이고 ;옮긴이: 양윤옥
# 8   9        9                   선량한 차별주의자                    김지혜 지음
# 9  10        9              쇼코의 미소 :최은영 소설                  지은이: 최은영
#
#   publisher publication_year         isbn13 무게_count
# 0        허블             2019  9791190090018     496g
# 1     팩토리나인             2020  9791165341909     358g
# ...

# %%
# 과제2 쪽수와 함께 위에서 추출한 다른 정보를 동시에 저장 #

def get_page_cnt(isbn):
    # Yes24 도서 검색 페이지 URL
    url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
    # URL에 ISBN을 넣어 HTML 가져옵니다.
    r = requests.get(url.format(isbn))
    soup = BeautifulSoup(r.text, 'html.parser')   # HTML 파싱
    # 검색 결과에서 해당 도서를 선택합니다.
    prd_info = soup.find('a', attrs={'class':'gd_name'})
    if prd_info == None:
        return ''
    # 도서 상세 페이지를 가져옵니다.
    url = 'http://www.yes24.com'+prd_info['href']
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    # 상품 상세정보 div를 선택합니다.
    prd_detail = soup.find('div', attrs={'id':'infoset_specific'})
    # 테이블에 있는 tr 태그를 가져옵니다.
    prd_tr_list = prd_detail.find_all('tr')
    # 쪽수가 들어 있는 th를 찾아 td에 담긴 값을 반환합니다.
    for tr in prd_tr_list:
        if tr.find('th').get_text() == '쪽수, 무게, 크기':
            return tr.find('td').get_text().split()[0]
    return ''

# %%
top10_books = books.head(10)

# %%
def get_page_cnt2(row):
    isbn = row['isbn13']
    return get_page_cnt(isbn)

# %%
page_count = top10_books.apply(get_page_cnt2, axis=1)
print(page_count)
# Out:
# 0    330쪽
# 1    300쪽
# 2    228쪽
# 3    340쪽
# 4    264쪽
# 5    396쪽
# 6    272쪽
# 7
# 8    244쪽
# 9    296쪽
# dtype: object

# %%
page_count = top10_books.apply(lambda row: get_page_cnt(row['isbn13']), axis=1)

# %%
page_count.name = 'page_count'
print(page_count)
# Out:
# 0    330쪽
# 1    300쪽
# 2    228쪽
# 3    340쪽
# 4    264쪽
# 5    396쪽
# 6    272쪽
# 7
# 8    244쪽
# 9    296쪽
# Name: page_count, dtype: object

# %%
top10_with_page_count = pd.merge(top10_with_무게_count, page_count, 
                                 left_index=True, right_index=True) 
top10_with_page_count
# Out:
#    no  ranking                     bookname                  authors  \
# 0   1        1  우리가 빛의 속도로 갈 수 없다면 :김초엽 소설                  지은이: 김초엽
# 1   2        2         달러구트 꿈 백화점.이미예 장편소설                  지은이: 이미예
# 2   3        3          지구에서 한아뿐 :정세랑 장편소설                  지은이: 정세랑
# 3   4        4           시선으로부터, :정세랑 장편소설                  지은이: 정세랑
# 4   5        5               아몬드 :손원평 장편소설                  지은이: 손원평
# 5   6        6            피프티 피플 :정세랑 장편소설                  지은이: 정세랑
# 6   7        7          목소리를 드릴게요 :정세랑 소설집                  지은이: 정세랑
# 7   8        8  나미야 잡화점의 기적 :히가시노 게이고 장편소설   지은이: 히가시노 게이고 ;옮긴이: 양윤옥
# 8   9        9                   선량한 차별주의자                    김지혜 지음
# 9  10        9              쇼코의 미소 :최은영 소설                  지은이: 최은영
#
#   publisher publication_year         isbn13 무게_count page_count
# 0        허블             2019  9791190090018     496g       330쪽
# 1     팩토리나인             2020  9791165341909     358g       300쪽
# ...
