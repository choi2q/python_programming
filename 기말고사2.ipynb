# %% [markdown]
# <a href="https://colab.research.google.com/github/choi2q/python_programming/blob/main/%EA%B8%B0%EB%A7%90%EA%B3%A0%EC%82%AC2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Sort the dataframe by 'loan_count_2017' column in descending order and select the top 50 books
top_50_books_2017 = common_books_df.sort_values('대출횟수(2017)', ascending=False).head(50)

# Compare the loan counts of the top 50 books in 2017 and 2023
top_50_books_2017['대출횟수(2023)'] = common_books_df.loc[top_50_books_2017.index, '대출횟수(2023)']

# Calculate the difference in loan counts between 2017 and 2023
top_50_books_2017['증감횟수'] = top_50_books_2017['대출횟수(2023)'] - top_50_books_2017['대출횟수(2017)']

# Separate the books with increased loan counts and decreased loan counts
increased_books = top_50_books_2017[top_50_books_2017['증감횟수'] > 0]
decreased_books = top_50_books_2017[top_50_books_2017['증감횟수'] < 0]

# Plot the loan count difference for each book
plt.figure(figsize=(12, 6))
plt.bar(increased_books['도서명'], increased_books['증감횟수'], color='green', label='대출 증가')
plt.bar(decreased_books['도서명'], decreased_books['증감횟수'], color='red', label='대출 감소')
plt.xticks(rotation=90)
plt.xlabel('도서명')
plt.ylabel('대출 횟수 증감')
plt.title('2017년 5월 대출 TOP 50 도서의 2023년 대출 횟수 증감')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-caa788d71ce2> in <cell line: 4>()
#       2
#       3 # Sort the dataframe by 'loan_count_2017' column in descending order and select the top 50 books
# ----> 4 top_50_books_2017 = common_books_df.sort_values('대출횟수(2017)', ascending=False).head(50)
#       5
#       6 # Compare the loan counts of the top 50 books in 2017 and 2023
#
# NameError: name 'common_books_df' is not defined

# %%
import matplotlib.pyplot as plt

# Sort the dataframe by '대출횟수(2017)' column in descending order and select the top 50 books
top_50_books_2017 = df.sort_values('대출횟수(2017)', ascending=False).head(50)

# Compare the loan counts of the top 50 books in 2017 and 2023
top_50_books_2017['대출횟수(2023)'] = df.loc[top_50_books_2017.index, '대출횟수(2023)']

# Calculate the difference in loan counts between 2017 and 2023
top_50_books_2017['증감횟수'] = top_50_books_2017['대출횟수(2023)'] - top_50_books_2017['대출횟수(2017)']

# Separate the books with increased loan counts and decreased loan counts
increased_books = top_50_books_2017[top_50_books_2017['증감횟수'] > 0]
decreased_books = top_50_books_2017[top_50_books_2017['증감횟수'] < 0]

# Plot the loan count difference for each book
plt.figure(figsize=(12, 6))
plt.bar(increased_books['도서명'], increased_books['증감횟수'], color='green', label='대출 증가')
plt.bar(decreased_books['도서명'], decreased_books['증감횟수'], color='red', label='대출 감소')
plt.xticks(rotation=90)
plt.xlabel('도서명')
plt.ylabel('대출 횟수 증감')
plt.title('2017년 5월 대출 TOP 50 도서의 2023년 대출 횟수 증감')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b5e1ef32134b> in <cell line: 4>()
#       2
#       3 # Sort the dataframe by '대출횟수(2017)' column in descending order and select the top 50 books
# ----> 4 top_50_books_2017 = df.sort_values('대출횟수(2017)', ascending=False).head(50)
#       5
#       6 # Compare the loan counts of the top 50 books in 2017 and 2023
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
from tabulate import tabulate

def download_data(url):
    response = requests.get(url)
    data = response.json()
    df = pd.DataFrame(data["response"]["docs"])
    df = df["doc"].apply(pd.Series)
    return df

# 2017년 5월 데이터 다운로드
url_2017 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2017-05-01&endDt=2017-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2017 = download_data(url_2017)

# 2023년 5월 데이터 다운로드
url_2023 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2023-05-01&endDt=2023-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2023 = download_data(url_2023)

# Convert 'loan_count' column to numeric type
df_2017['loan_count'] = pd.to_numeric(df_2017['loan_count'])
df_2023['loan_count'] = pd.to_numeric(df_2023['loan_count'])


# Sort the dataframe by 'loan_count_2017' column in descending order and select the top 50 books
top_50_books_2017 = merged_df.sort_values('loan_count_2017', ascending=False).head(50)

# Compare the loan counts of the top 50 books in 2017 and 2023
top_50_books_2017['loan_count_2023'] = merged_df.loc[top_50_books_2017.index, 'loan_count_2023']

# Calculate the difference in loan counts between 2017 and 2023
top_50_books_2017['count_change'] = top_50_books_2017['loan_count_2023'] - top_50_books_2017['loan_count_2017']

# Separate the books with increased loan counts and decreased loan counts
increased_books = top_50_books_2017[top_50_books_2017['count_change'] > 0]
decreased_books = top_50_books_2017[top_50_books_2017['count_change'] < 0]

# Plot the loan count difference for each book
plt.figure(figsize=(12, 6))
plt.bar(increased_books['Book'], increased_books['count_change'], color='green', label='Increased')
plt.bar(decreased_books['Book'], decreased_books['count_change'], color='red', label='Decreased')
plt.xticks(rotation=90)
plt.xlabel('Book')
plt.ylabel('Loan Count Change')
plt.title('Comparison of Loan Counts between 2017 and 2023 for Top 50 Books in May')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6199f7ef94d4> in <cell line: 27>()
#      25
#      26 # Sort the dataframe by 'loan_count_2017' column in descending order and select the top 50 books
# ---> 27 top_50_books_2017 = merged_df.sort_values('loan_count_2017', ascending=False).head(50)
#      28
#      29 # Compare the loan counts of the top 50 books in 2017 and 2023
#
# NameError: name 'merged_df' is not defined

# %%
import matplotlib.pyplot as plt

# Sort the DataFrame by 'loan_count_2017' column in descending order and select the top 50 books
top_50_books_2017 = df.sort_values('대출횟수(2017)', ascending=False).head(50)

# Compare the loan counts of the top 50 books in 2017 and 2023
top_50_books_2017['대출횟수(2023)'] = df.loc[top_50_books_2017.index, '대출횟수(2023)']

# Calculate the difference in loan counts between 2017 and 2023
top_50_books_2017['대출횟수 변화'] = top_50_books_2017['대출횟수(2023)'] - top_50_books_2017['대출횟수(2017)']

# Separate the books with increased loan counts and decreased loan counts
increased_books = top_50_books_2017[top_50_books_2017['대출횟수 변화'] > 0]
decreased_books = top_50_books_2017[top_50_books_2017['대출횟수 변화'] < 0]

# Plot the loan count difference for each book
plt.figure(figsize=(12, 6))
plt.bar(increased_books['Book'], increased_books['대출횟수 변화'], color='green', label='대출 증가')
plt.bar(decreased_books['Book'], decreased_books['대출횟수 변화'], color='red', label='대출 감소')
plt.xticks(rotation=90)
plt.xlabel('도서')
plt.ylabel('대출 횟수 변화')
plt.title('2017년 5월 대출 TOP 50 도서의 2023년 대출 횟수 변화')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f5014ea79cea> in <cell line: 4>()
#       2
#       3 # Sort the DataFrame by 'loan_count_2017' column in descending order and select the top 50 books
# ----> 4 top_50_books_2017 = df.sort_values('대출횟수(2017)', ascending=False).head(50)
#       5
#       6 # Compare the loan counts of the top 50 books in 2017 and 2023
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
from tabulate import tabulate

def download_data(url):
    response = requests.get(url)
    data = response.json()
    df = pd.DataFrame(data["response"]["docs"])
    df = df["doc"].apply(pd.Series)
    return df

# 2017년 5월 데이터 다운로드
url_2017 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2017-05-01&endDt=2017-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2017 = download_data(url_2017)

# 2023년 5월 데이터 다운로드
url_2023 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2023-05-01&endDt=2023-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2023 = download_data(url_2023)

# Convert 'loan_count' column to numeric type
df_2017['loan_count'] = pd.to_numeric(df_2017['loan_count'])
df_2023['loan_count'] = pd.to_numeric(df_2023['loan_count'])

# Sort the dataframe by 'loan_count' column in descending order and select the top 50 books in 2017
top_50_books_2017 = df_2017.sort_values('loan_count', ascending=False).head(50)

# Compare the loan counts of the top 50 books in 2017 and 2023
top_50_books_2017['loan_count_2023'] = df_2023.loc[top_50_books_2017.index, 'loan_count']

# Calculate the difference in loan counts between 2017 and 2023
top_50_books_2017['count_change'] = top_50_books_2017['loan_count_2023'] - top_50_books_2017['loan_count']

# Separate the books with increased loan counts and decreased loan counts
increased_books = top_50_books_2017[top_50_books_2017['count_change'] > 0]
decreased_books = top_50_books_2017[top_50_books_2017['count_change'] < 0]

# Plot the loan count difference for each book
plt.figure(figsize=(12, 6))
plt.bar(increased_books['bookname'], increased_books['count_change'], color='green', label='Increased')
plt.bar(decreased_books['bookname'], decreased_books['count_change'], color='red', label='Decreased')
plt.xticks(rotation=90)
plt.xlabel('Book')
plt.ylabel('Loan Count Change')
plt.title('Comparison of Loan Counts between 2017 and 2023 for Top 50 Books in May')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import requests
import pandas as pd
from tabulate import tabulate

# Set the font family to 'sans-serif'
plt.rcParams['font.family'] = 'sans-serif'

def download_data(url):
    response = requests.get(url)
    data = response.json()
    df = pd.DataFrame(data["response"]["docs"])
    df = df["doc"].apply(pd.Series)
    return df

# 2017년 5월 데이터 다운로드
url_2017 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2017-05-01&endDt=2017-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2017 = download_data(url_2017)

# 2023년 5월 데이터 다운로드
url_2023 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2023-05-01&endDt=2023-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2023 = download_data(url_2023)

# Convert 'loan_count' column to numeric type
df_2017['loan_count'] = pd.to_numeric(df_2017['loan_count'])
df_2023['loan_count'] = pd.to_numeric(df_2023['loan_count'])

# Sort the dataframe by 'loan_count' column in descending order and select the top 50 books in 2017
top_50_books_2017 = df_2017.sort_values('loan_count', ascending=False).head(50)

# Compare the loan counts of the top 50 books in 2017 and 2023
top_50_books_2017['loan_count_2023'] = df_2023.loc[top_50_books_2017.index, 'loan_count']

# Calculate the difference in loan counts between 2017 and 2023
top_50_books_2017['count_change'] = top_50_books_2017['loan_count_2023'] - top_50_books_2017['loan_count']

# Separate the books with increased loan counts and decreased loan counts
increased_books = top_50_books_2017[top_50_books_2017['count_change'] > 0]
decreased_books = top_50_books_2017[top_50_books_2017['count_change'] < 0]

# Plot the loan count difference for each book
plt.figure(figsize=(12, 6))
plt.bar(increased_books['bookname'], increased_books['count_change'], color='green', label='Increased')
plt.bar(decreased_books['bookname'], decreased_books['count_change'], color='red', label='Decreased')
plt.xticks(rotation=90)
plt.xlabel('Book')
plt.ylabel('Loan Count Change')
plt.title('Comparison of Loan Counts between 2017 and 2023 for Top 50 Books in May')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as font_manager
import requests
import pandas as pd
from tabulate import tabulate

# Install the 'NanumGothic' font
# !apt-get install -y fonts-nanum
# !fc-cache -fv

# Set the font family
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
font_prop = font_manager.FontProperties(fname=font_path)
plt.rcParams['font.family'] = font_prop.get_name()

def download_data(url):
    response = requests.get(url)
    data = response.json()
    df = pd.DataFrame(data["response"]["docs"])
    df = df["doc"].apply(pd.Series)
    return df

# Download the data for May 2017
url_2017 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2017-05-01&endDt=2017-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2017 = download_data(url_2017)

# Download the data for May 2023
url_2023 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2023-05-01&endDt=2023-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2023 = download_data(url_2023)

# Convert 'loan_count' column to numeric type
df_2017['loan_count'] = pd.to_numeric(df_2017['loan_count'])
df_2023['loan_count'] = pd.to_numeric(df_2023['loan_count'])

# Merge the dataframes based on the 'no' column
merged_df = pd.merge(df_2017, df_2023, on='no', suffixes=('_2017', '_2023'))

# Sort the dataframe by 'loan_count_2017' column in descending order and select the top 50 books
top_50_books_2017 = merged_df.sort_values('loan_count_2017', ascending=False).head(50)

# Compare the loan counts of the top 50 books in 2017 and 2023
top_50_books_2017['loan_count_2023'] = merged_df.loc[top_50_books_2017.index, 'loan_count_2023']

# Calculate the difference in loan counts between 2017 and 2023
top_50_books_2017['count_change'] = top_50_books_2017['loan_count_2023'] - top_50_books_2017['loan_count_2017']

# Separate the books with increased loan counts and decreased loan counts
increased_books = top_50_books_2017[top_50_books_2017['count_change'] > 0]
decreased_books = top_50_books_2017[top_50_books_2017['count_change'] < 0]

# Plot the loan count difference for each book
plt.figure(figsize=(12, 6))
plt.bar(increased_books['bookname_2017'], increased_books['count_change'], color='green', label='Increased')
plt.bar(decreased_books['bookname_2017'], decreased_books['count_change'], color='red', label='Decreased')
plt.xticks(rotation=90)
plt.xlabel('Book')
plt.ylabel('Loan Count Change')
plt.title('Comparison of Loan Counts between 2017 and 2023 for Top 50 Books in May')
plt.legend()
plt.show()
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20180306-3).
# 0 upgraded, 0 newly installed, 0 to remove and 38 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# /usr/share/fonts/truetype/liberation: skipping, looped directory detected
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import requests
import pandas as pd

def download_data(url):
    response = requests.get(url)
    data = response.json()
    df = pd.DataFrame(data["response"]["docs"])
    df = df["doc"].apply(pd.Series)
    return df

# Download the data for May 2017
url_2017 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2017-05-01&endDt=2017-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2017 = download_data(url_2017)

# Download the data for May 2023
url_2023 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2023-05-01&endDt=2023-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2023 = download_data(url_2023)

# Convert 'loan_count' column to numeric type
df_2017['loan_count'] = pd.to_numeric(df_2017['loan_count'])
df_2023['loan_count'] = pd.to_numeric(df_2023['loan_count'])

# Merge the dataframes based on the 'no' column
merged_df = pd.merge(df_2017, df_2023, on='no', suffixes=('_2017', '_2023'))

# Sort the dataframe by 'loan_count_2017' column in descending order and select the top 50 books
top_50_books_2017 = merged_df.sort_values('loan_count_2017', ascending=False).head(50)

# Compare the loan counts of the top 50 books in 2017 and 2023
top_50_books_2017['loan_count_2023'] = merged_df.loc[top_50_books_2017.index, 'loan_count_2023']

# Calculate the difference in loan counts between 2017 and 2023
top_50_books_2017['count_change'] = top_50_books_2017['loan_count_2023'] - top_50_books_2017['loan_count_2017']

# Separate the books with increased loan counts and decreased loan counts
increased_books = top_50_books_2017[top_50_books_2017['count_change'] > 0]
decreased_books = top_50_books_2017[top_50_books_2017['count_change'] < 0]

# Set the font path to NanumGothic font
font_path = '/usr/share/fonts/truetype/nanum/NanumGothic.ttf'
fontprop = fm.FontProperties(fname=font_path)

# Plot the loan count difference for each book
plt.figure(figsize=(12, 6))
plt.bar(increased_books['bookname_2017'], increased_books['count_change'], color='green', label='Increased')
plt.bar(decreased_books['bookname_2017'], decreased_books['count_change'], color='red', label='Decreased')
plt.xticks(rotation=90, fontproperties=fontprop)
plt.xlabel('Book', fontproperties=fontprop)
plt.ylabel('Loan Count Change', fontproperties=fontprop)
plt.title('Comparison of Loan Counts between 2017 and 2023 for Top 50 Books in May', fontproperties=fontprop)
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'NanumGothic' not found.
# ...

# %%
import matplotlib.pyplot as plt
import requests
import pandas as pd
from tabulate import tabulate
from matplotlib import font_manager

# Download font
font_url = 'https://cdn.jsdelivr.net/npm/nanumgothic@1.0.0/nanumgothic.css'
font_manager.fontManager.add_url(font_url)

# Set font properties
font_properties = font_manager.FontProperties(fname='NanumGothic')

def download_data(url):
    response = requests.get(url)
    data = response.json()
    df = pd.DataFrame(data["response"]["docs"])
    df = df["doc"].apply(pd.Series)
    return df

# 2017년 5월 데이터 다운로드
url_2017 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2017-05-01&endDt=2017-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2017 = download_data(url_2017)

# 2023년 5월 데이터 다운로드
url_2023 = 'http://data4library.kr/api/loanItemSrch?libCode=111344&format=json&startDt=2023-05-01&endDt=2023-05-31&dtl_region=11040&authKey=c01ec15e4574f74ee45cba2601bad15b82971e606e3b0740977ee4b363ce2fe2'
df_2023 = download_data(url_2023)

# Convert 'loan_count' column to numeric type
df_2017['loan_count'] = pd.to_numeric(df_2017['loan_count'])
df_2023['loan_count'] = pd.to_numeric(df_2023['loan_count'])

# Merge the dataframes based on the book name
merged_df = pd.merge(df_2017, df_2023, on='bookname', suffixes=('_2017', '_2023'))

# Sort the dataframe by 'loan_count_2017' column in descending order and select the top 50 books
top_50_books_2017 = merged_df.sort_values('loan_count_2017', ascending=False).head(50)

# Compare the loan counts of the top 50 books in 2017 and 2023
top_50_books_2017['loan_count_2023'] = merged_df.loc[top_50_books_2017.index, 'loan_count_2023']

# Calculate the difference in loan counts between 2017 and 2023
top_50_books_2017['count_change'] = top_50_books_2017['loan_count_2023'] - top_50_books_2017['loan_count_2017']

# Separate the books with increased loan counts and decreased loan counts
increased_books = top_50_books_2017[top_50_books_2017['count_change'] > 0]
decreased_books = top_50_books_2017[top_50_books_2017['count_change'] < 0]

# Plot the loan count change for the top 50 books
plt.figure(figsize=(12, 6))
plt.barh(increased_books['bookname'], increased_books['count_change'], color='green', label='Increased')
plt.barh(decreased_books['bookname'], decreased_books['count_change'], color='red', label='Decreased')
plt.xlabel('Loan Count Change')
plt.ylabel('Book Title')
plt.title('Loan Count Change for Top 50 Books')
plt.legend()
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().xaxis.set_tick_params(width=0.5)
plt.gca().yaxis.set_tick_params(width=0.5)
plt.xticks(fontproperties=font_properties)
plt.yticks(fontproperties=font_properties)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-4c5da0b85262> in <cell line: 9>()
#       7 # Download font
#       8 font_url = 'https://cdn.jsdelivr.net/npm/nanumgothic@1.0.0/nanumgothic.css'
# ----> 9 font_manager.fontManager.add_url(font_url)
#      10
#      11 # Set font properties
#
# AttributeError: 'FontManager' object has no attribute 'add_url'
